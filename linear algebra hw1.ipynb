# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import math

# %%
R = 4
r = 0.06
w = 45
t = np.arange(0,2*np.pi,0.001)
x = (R-r)*np.cos(t) + w*r*np.cos((R-r)*t/r)
y = (R-r)*np.sin(t) - w*r*np.sin((R-r)*t/r)
"""R,r,w and the precision of t are changeable"""
# Out:
# 'R,r,w and the precision of t are changeable'

# %%
plt.plot(x,y)

# %%
t = np.arange(0,2*np.pi,0.01)
plt.scatter(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
t = np.arange(0,2*np.pi,0.1)
plt.scatter(x,y)
